# %% [markdown]
# ### Credential's

# %% [markdown]
# #### Name : Mayank Anand
# #### Email : mayankanand2701@gmail.com

# %% [markdown]
# ### Part 1

# %% [markdown]
# ### Part 2

# %%
import matplotlib.pyplot as plt 
import cv2 as cv

# %%
img1 = plt.imread('Dataset/2.png')
img1
# Out:
# array([[[0.9882353 , 0.9764706 , 0.95686275, 1.        ],
#         [0.98039216, 0.9764706 , 0.9607843 , 1.        ],
#         [0.9843137 , 0.98039216, 0.9647059 , 1.        ],
#         ...,
#         [0.6509804 , 0.6784314 , 0.654902  , 1.        ],
#         [0.6431373 , 0.6745098 , 0.64705884, 1.        ],
#         [0.6313726 , 0.6666667 , 0.6431373 , 1.        ]],
#
#        [[0.9843137 , 0.972549  , 0.9529412 , 1.        ],
#         [0.98039216, 0.9764706 , 0.95686275, 1.        ],
#         [0.98039216, 0.9764706 , 0.95686275, 1.        ],
#         ...,
#         [0.654902  , 0.68235296, 0.65882355, 1.        ],
#         [0.6509804 , 0.6784314 , 0.6509804 , 1.        ],
#         [0.6392157 , 0.67058825, 0.6431373 , 1.        ]],
#
#        [[0.98039216, 0.96862745, 0.9411765 , 1.        ],
#         [0.9764706 , 0.96862745, 0.94509804, 1.        ],
#         [0.9764706 , 0.972549  , 0.9490196 , 1.        ],
#         ...,
# ...

# %%
plt.imshow(img1)

# %%
plt.hist(img1.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
# Out:
# (array([1.39000e+03, 8.57000e+02, 6.87000e+02, 5.72000e+02, 4.51000e+02,
#         3.71000e+02, 3.22000e+02, 2.97000e+02, 2.55000e+02, 2.40000e+02,
#         1.88000e+02, 1.94000e+02, 1.78000e+02, 1.56000e+02, 1.57000e+02,
#         1.44000e+02, 1.27000e+02, 1.36000e+02, 1.03000e+02, 1.03000e+02,
#         8.10000e+01, 9.60000e+01, 9.30000e+01, 8.90000e+01, 8.40000e+01,
#         7.20000e+01, 5.80000e+01, 5.90000e+01, 7.60000e+01, 6.00000e+01,
#         5.10000e+01, 5.70000e+01, 6.80000e+01, 8.40000e+01, 1.10000e+02,
#         1.72000e+02, 3.29000e+02, 4.79000e+02, 6.17000e+02, 5.83000e+02,
#         6.08000e+02, 5.75000e+02, 5.43000e+02, 5.64000e+02, 5.71000e+02,
#         5.58000e+02, 5.63000e+02, 5.27000e+02, 4.52000e+02, 3.64000e+02,
#         2.98000e+02, 3.12000e+02, 2.51000e+02, 2.25000e+02, 2.04000e+02,
#         2.05000e+02, 1.84000e+02, 1.90000e+02, 1.69000e+02, 1.66000e+02,
#         1.55000e+02, 1.63000e+02, 1.92000e+02, 1.93000e+02, 1.76000e+02,
# ...

# %%
# load an image in grayscale mode
imgGray1 = cv.imread('3.png',0)

# calculate frequency of pixels in range 0-255
histogram = cv.calcHist([imgGray1],[0],None,[256],[0,256]) 
plt.plot(histogram)
plt.show()
