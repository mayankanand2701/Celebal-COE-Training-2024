# %% [markdown]
# ### Credential's

# %% [markdown]
# #### Name : Mayank Anand
# #### Registration Number : 2141001045

# %%
# importing libraries

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Exploratory data analysis (EDA)

# %%
# to load the dataset

df = pd.read_csv("Train Data.csv")

# %%
# to view the first few data's of the dataframe

df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# to view the last few data's of the dataframe

df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# to display about the total number of rows and columns in the dataset

df.shape
# Out:
# (1460, 81)

# %%
# to get info of dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# to get statistical information about the dataset

df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# to get statistical information about the dataset along with the categorical column

df.describe(include='object')
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
# to know about number of duplicates row's in the dataframe

df.duplicated().sum()
# Out:
# 0

# %%
# to know about the missing value in the datafrmae

df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# ### Handling Missing Values

# %%
# to drop the Id column which is unnecssary for the dataset

df.drop('Id', axis= 1, inplace = True)

# %%
# to view all the columns present in the dataset

df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
# To drop the columns that has data missing greater than 20 %

threshold = len(df)*0.20
column = df.isna().sum() > threshold
columnToBeDropped = df.columns[column]

# %%
# To know how many columns follow the above condion

columnToBeDropped.shape
# Out:
# (5,)

# %%
# To drop the columns that all follow the above condition

df.drop(columnToBeDropped, axis= 1, inplace = True)
df.shape
# Out:
# (1460, 75)

# %%
# To know how the names of columns that are remaing after removig the above columns

df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
# To know the count of different type of data types present in the dataset 

df.dtypes.value_counts()
# Out:
# object     38
# int64      34
# float64     3
# dtype: int64

# %%
# To check how many null values exist in the dataframe

df.isna().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 75, dtype: int64

# %%
# To check the percentage of how many data are null in the dataset

df.isnull().sum()/len(df)
# Out:
# MSSubClass       0.000000
# MSZoning         0.000000
# LotFrontage      0.177397
# LotArea          0.000000
# Street           0.000000
#                    ...
# MoSold           0.000000
# YrSold           0.000000
# SaleType         0.000000
# SaleCondition    0.000000
# SalePrice        0.000000
# Length: 75, dtype: float64

# %%
# To check the duplicate rows in the dataframe

df.duplicated().sum()
# Out:
# 0

# %%
# To get statistical details about the Sale Price Column

df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# To get a visual view about the Sale Price Column

df["SalePrice"].hist(bins=50);

# %%
# To drop the columns due to low variability

df.drop(
    [
        "Street",
        "Utilities",
        "Condition2",
        "RoofMatl",
        "ExterCond",
        "BsmtCond",
        "Heating",
        "GarageCond",
    ],
    axis=1,
    inplace=True,
)

# %%
# To know the shape of the dataframe after removing certain columns

df.shape
# Out:
# (1460, 67)

# %%
# To replace the  missing data in numeric columns by median

for col in df.select_dtypes(include=['int64','float64']):
    if df[col].isnull().sum() > 0:
        median_value = df[col].median()
        df[col].fillna(median_value, inplace=True)

# %%
# To check how many null values exist in the dataframe after performing the above replacement opeation

df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# LotShape         0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 67, dtype: int64

# %%
# To Handle missing data in categorical columns by mode

for col in df.select_dtypes(include=['object']):
    if df[col].isnull().sum() > 0:
        mode_value = df[col].mode()[0]
        df[col].fillna(mode_value, inplace=True)

# %%
# To check whether we have any null values present or not

df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# LotShape         0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 67, dtype: int64

# %% [markdown]
# ### Data Transformation & Reduction & Feature Engineering

# %%
# To combine the both column to one

df["Total_floors"] = df["1stFlrSF"] + df["2ndFlrSF"]
df["Total_floors"].head()
# Out:
# 0    1710
# 1    1262
# 2    1786
# 3    1717
# 4    2198
# Name: Total_floors, dtype: int64

# %%
# To combine the both column to one

df["House_quality_score"] = df["OverallCond"] * df["OverallQual"]
df["House_quality_score"].head()
# Out:
# 0    35
# 1    48
# 2    35
# 3    35
# 4    40
# Name: House_quality_score, dtype: int64

# %%
# To combine the three column to one

df["Total_porch_area"] = (
    df["OpenPorchSF"] + df["EnclosedPorch"] + df["3SsnPorch"] + df["ScreenPorch"]
)
df["Total_porch_area"].head()
# Out:
# 0     61
# 1      0
# 2     42
# 3    307
# 4     84
# Name: Total_porch_area, dtype: int64

# %%
# To combine the both column to one

df["TotalBsmtFinSF"] = df["BsmtFinSF1"] + df["BsmtFinSF2"]

# %%
# To combine the both column to one

df["TotalFullBath"] = df["BsmtFullBath"] + df["FullBath"]
df["TotalHalfBath"] = df["BsmtHalfBath"] + df["HalfBath"]

# %%
# # To drop the irrelevant columns

df.drop(
    [
        "BsmtFullBath",
        "FullBath",
        "BsmtHalfBath",
        "HalfBath",
        "OpenPorchSF",
        "EnclosedPorch",
        "3SsnPorch",
        "ScreenPorch",
        "OverallCond",
        "OverallQual",
        "1stFlrSF",
        "2ndFlrSF",
    ],
    axis=1,
    inplace=True,
)

# %%
# To know the shape of the dataframe after performing the cleaning operations

df.shape
# Out:
# (1460, 61)

# %%
# To know the count of different type of data types present in the dataset 

df.dtypes.value_counts()
# Out:
# object     30
# int64      28
# float64     3
# dtype: int64

# %%
# To visualise the dataframe after perfoming the operations

df.head(5)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# 0          60       RL         65.0     8450      Reg         Lvl    Inside
# 1          20       RL         80.0     9600      Reg         Lvl       FR2
# 2          60       RL         68.0    11250      IR1         Lvl    Inside
# 3          70       RL         60.0     9550      IR1         Lvl    Corner
# 4          60       RL         84.0    14260      IR1         Lvl       FR2
#
#   LandSlope Neighborhood Condition1  ... YrSold SaleType  SaleCondition  \
# 0       Gtl      CollgCr       Norm  ...   2008       WD         Normal
# 1       Gtl      Veenker      Feedr  ...   2007       WD         Normal
# 2       Gtl      CollgCr       Norm  ...   2008       WD         Normal
# 3       Gtl      Crawfor       Norm  ...   2006       WD        Abnorml
# 4       Gtl      NoRidge       Norm  ...   2008       WD         Normal
#
# ...

# %% [markdown]
# ### Encoding Categorical Columns

# %%
# To load the Preprocessing

from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# To iterate over all columns in the DataFrame

for col in df.select_dtypes(include=['object']).columns:
    df[col] = label_encoder.fit_transform(df[col])

# %%
df.head(5)
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# 0          60         3         65.0     8450         3            3
# 1          20         3         80.0     9600         3            3
# 2          60         3         68.0    11250         0            3
# 3          70         3         60.0     9550         0            3
# 4          60         3         84.0    14260         0            3
#
#    LotConfig  LandSlope  Neighborhood  Condition1  ...  YrSold  SaleType  \
# 0          4          0             5           2  ...    2008         8
# 1          2          0            24           1  ...    2007         8
# 2          4          0             5           2  ...    2008         8
# 3          0          0             6           2  ...    2006         8
# 4          2          0            15           2  ...    2008         8
#
#    SaleCondition  SalePrice  Total_floors  House_quality_score  \
# ...

# %%
# To know the count of different type of data types present in the dataset 

df.dtypes.value_counts()
# Out:
# int32      30
# int64      28
# float64     3
# dtype: int64
